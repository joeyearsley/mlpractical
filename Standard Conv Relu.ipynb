# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = []  # remove any existing handlers
file_handler = logging.FileHandler('scr.log')
file_handler.setFormatter(logging.Formatter(
    '%(name)s:%(levelname)s %(message)s'))
logger.addHandler(file_handler)

# %%
#Baseline experiment
import numpy
import logging
import shelve
from mlp.dataset import MNISTDataProvider

logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Standard Conv Relu for 10 epochs')
logger.info('Initialising data providers...')

train_dp = MNISTDataProvider(dset='train', batch_size=10, max_num_batches=100, randomize=True, conv_reshape = True )
valid_dp = MNISTDataProvider(dset='valid', batch_size=1000, max_num_batches=-10, randomize=False, conv_reshape = True)
test_dp = MNISTDataProvider(dset='eval', batch_size=1000, max_num_batches=-10, randomize=False, conv_reshape = True)

from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.conv import ConvRelu, ConvMaxPool2D
from mlp.optimisers import SGDOptimiser #import the optimiser

from mlp.costs import CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

logger = logging.getLogger()
logger.setLevel(logging.INFO)
rng = numpy.random.RandomState([2015,10,10])

#some hyper-parameters
nhid = 800
learning_rate = 0.5
max_epochs = 30
cost = CECost()
    
stats = []

train_dp.reset()
valid_dp.reset()
test_dp.reset()

#define the model
model = MLP(cost=cost)
model.add_layer(ConvRelu(num_inp_feat_maps = 1, num_out_feat_maps = 2, irange=0.2, rng=rng))
model.add_layer(ConvMaxPool2D(num_feat_maps = 2, conv_shape = (24,24)))
model.add_layer(Sigmoid(idim=2*12*12, odim=2*12*12, irange=0.2, rng=rng))
model.add_layer(Softmax(idim=2*12*12, odim=10, rng=rng))

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs
lr_scheduler = LearningRateFixed(learning_rate=learning_rate, max_epochs=max_epochs)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.info('Training started...')
tr_stats, valid_stats = optimiser.train(model, train_dp, valid_dp)

logger.info('Testing the model on test set:')
tst_cost, tst_accuracy = optimiser.validate(model, test_dp)
logger.info('MNIST test set accuracy is %.2f %%, cost (%s) is %.3f'%(tst_accuracy*100., cost.get_name(), tst_cost))

stats.append((tr_stats, valid_stats, (tst_cost, tst_accuracy)))

shelve_r['results'] = (tr_stats, valid_stats, (tst_cost, tst_accuracy))

shelve_r.close()
# Out:
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# ...
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# (10, 2, 12, 12)
# (2, 1, 5, 5) temp
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bf4df7d79757> in <module>()
#      58 stats.append((tr_stats, valid_stats, (tst_cost, tst_accuracy)))
#      59
# ---> 60 shelve_r['results'] = (tr_stats, valid_stats, (tst_cost, tst_accuracy))
#      61
#      62 shelve_r.close()
#
# NameError: name 'shelve_r' is not defined

# %%
with open('scr.log', 'r') as log_file:
    print log_file.read()
# Out:
# root:INFO Standard Conv Relu for 10 epochs
# root:INFO Initialising data providers...
# root:INFO Training started...
# mlp.optimisers:INFO Epoch 0: Training cost (ce) for initial model is 2.375. Accuracy is 10.60%
# mlp.optimisers:INFO Epoch 0: Validation cost (ce) for initial model is 2.394. Accuracy is 9.91%
# mlp.optimisers:INFO Epoch 1: Training cost (ce) is 2.380. Accuracy is 31.40%
# mlp.optimisers:INFO Epoch 1: Validation cost (ce) is 1.525. Accuracy is 44.12%
# mlp.optimisers:INFO Epoch 1: Took 294 seconds. Training speed 23 pps. Validation speed 40 pps.
# mlp.optimisers:INFO Epoch 2: Training cost (ce) is 1.630. Accuracy is 39.40%
# mlp.optimisers:INFO Epoch 2: Validation cost (ce) is 1.619. Accuracy is 40.71%
# mlp.optimisers:INFO Epoch 2: Took 296 seconds. Training speed 23 pps. Validation speed 40 pps.
# mlp.optimisers:INFO Epoch 3: Training cost (ce) is 1.694. Accuracy is 38.90%
# mlp.optimisers:INFO Epoch 3: Validation cost (ce) is 1.840. Accuracy is 35.01%
# mlp.optimisers:INFO Epoch 3: Took 295 seconds. Training speed 23 pps. Validation speed 40 pps.
# mlp.optimisers:INFO Epoch 4: Training cost (ce) is 1.760. Accuracy is 37.90%
# mlp.optimisers:INFO Epoch 4: Validation cost (ce) is 1.727. Accuracy is 40.16%
# mlp.optimisers:INFO Epoch 4: Took 303 seconds. Training speed 22 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 5: Training cost (ce) is 2.043. Accuracy is 32.90%
# mlp.optimisers:INFO Epoch 5: Validation cost (ce) is 2.313. Accuracy is 32.98%
# mlp.optimisers:INFO Epoch 5: Took 302 seconds. Training speed 22 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 6: Training cost (ce) is 2.736. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 6: Validation cost (ce) is 2.764. Accuracy is 26.15%
# mlp.optimisers:INFO Epoch 6: Took 302 seconds. Training speed 22 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 7: Training cost (ce) is 2.649. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 7: Validation cost (ce) is 2.099. Accuracy is 32.24%
# mlp.optimisers:INFO Epoch 7: Took 301 seconds. Training speed 22 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 8: Training cost (ce) is 2.306. Accuracy is 31.50%
# mlp.optimisers:INFO Epoch 8: Validation cost (ce) is 2.277. Accuracy is 27.72%
# mlp.optimisers:INFO Epoch 8: Took 300 seconds. Training speed 22 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 9: Training cost (ce) is 2.389. Accuracy is 31.30%
# mlp.optimisers:INFO Epoch 9: Validation cost (ce) is 3.233. Accuracy is 22.51%
# mlp.optimisers:INFO Epoch 9: Took 299 seconds. Training speed 23 pps. Validation speed 39 pps.
# mlp.optimisers:INFO Epoch 10: Training cost (ce) is 3.094. Accuracy is 25.10%
# mlp.optimisers:INFO Epoch 10: Validation cost (ce) is 4.496. Accuracy is 25.37%
# mlp.optimisers:INFO Epoch 10: Took 300 seconds. Training speed 23 pps. Validation speed 39 pps.
# root:INFO Testing the model on test set:
# root:INFO MNIST test set accuracy is 27.12 %, cost (ce) is 4.419
# root:INFO Standard Conv Relu for 10 epochs
# root:INFO Initialising data providers...
# root:INFO Training started...
# mlp.optimisers:INFO Epoch 0: Training cost (ce) for initial model is 2.375. Accuracy is 10.60%
# mlp.optimisers:INFO Epoch 0: Validation cost (ce) for initial model is 2.394. Accuracy is 9.91%
# mlp.optimisers:INFO Epoch 1: Training cost (ce) is 2.380. Accuracy is 31.40%
# mlp.optimisers:INFO Epoch 1: Validation cost (ce) is 1.525. Accuracy is 44.12%
# mlp.optimisers:INFO Epoch 1: Took 234 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 2: Training cost (ce) is 1.630. Accuracy is 39.40%
# mlp.optimisers:INFO Epoch 2: Validation cost (ce) is 1.619. Accuracy is 40.71%
# mlp.optimisers:INFO Epoch 2: Took 234 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 3: Training cost (ce) is 1.694. Accuracy is 38.90%
# mlp.optimisers:INFO Epoch 3: Validation cost (ce) is 1.840. Accuracy is 35.01%
# mlp.optimisers:INFO Epoch 3: Took 234 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 4: Training cost (ce) is 1.760. Accuracy is 37.90%
# mlp.optimisers:INFO Epoch 4: Validation cost (ce) is 1.727. Accuracy is 40.16%
# mlp.optimisers:INFO Epoch 4: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 5: Training cost (ce) is 2.043. Accuracy is 32.90%
# mlp.optimisers:INFO Epoch 5: Validation cost (ce) is 2.313. Accuracy is 32.98%
# mlp.optimisers:INFO Epoch 5: Took 234 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 6: Training cost (ce) is 2.736. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 6: Validation cost (ce) is 2.764. Accuracy is 26.15%
# mlp.optimisers:INFO Epoch 6: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 7: Training cost (ce) is 2.649. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 7: Validation cost (ce) is 2.099. Accuracy is 32.24%
# mlp.optimisers:INFO Epoch 7: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 8: Training cost (ce) is 2.306. Accuracy is 31.50%
# mlp.optimisers:INFO Epoch 8: Validation cost (ce) is 2.277. Accuracy is 27.72%
# mlp.optimisers:INFO Epoch 8: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 9: Training cost (ce) is 2.389. Accuracy is 31.30%
# mlp.optimisers:INFO Epoch 9: Validation cost (ce) is 3.233. Accuracy is 22.51%
# mlp.optimisers:INFO Epoch 9: Took 234 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 10: Training cost (ce) is 3.094. Accuracy is 25.10%
# mlp.optimisers:INFO Epoch 10: Validation cost (ce) is 4.496. Accuracy is 25.37%
# mlp.optimisers:INFO Epoch 10: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 11: Training cost (ce) is 3.214. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 11: Validation cost (ce) is 3.635. Accuracy is 25.76%
# mlp.optimisers:INFO Epoch 11: Took 235 seconds. Training speed 22 pps. Validation speed 53 pps.
# mlp.optimisers:INFO Epoch 12: Training cost (ce) is 3.411. Accuracy is 27.20%
# mlp.optimisers:INFO Epoch 12: Validation cost (ce) is 4.061. Accuracy is 25.26%
# mlp.optimisers:INFO Epoch 12: Took 235 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 13: Training cost (ce) is 3.401. Accuracy is 25.70%
# mlp.optimisers:INFO Epoch 13: Validation cost (ce) is 3.770. Accuracy is 24.78%
# mlp.optimisers:INFO Epoch 13: Took 236 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 14: Training cost (ce) is 2.844. Accuracy is 30.90%
# mlp.optimisers:INFO Epoch 14: Validation cost (ce) is 3.886. Accuracy is 26.17%
# mlp.optimisers:INFO Epoch 14: Took 235 seconds. Training speed 22 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 15: Training cost (ce) is 3.351. Accuracy is 27.80%
# mlp.optimisers:INFO Epoch 15: Validation cost (ce) is 2.109. Accuracy is 31.95%
# mlp.optimisers:INFO Epoch 15: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 16: Training cost (ce) is 3.197. Accuracy is 28.40%
# mlp.optimisers:INFO Epoch 16: Validation cost (ce) is 4.832. Accuracy is 23.66%
# mlp.optimisers:INFO Epoch 16: Took 238 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 17: Training cost (ce) is 3.618. Accuracy is 27.30%
# mlp.optimisers:INFO Epoch 17: Validation cost (ce) is 3.553. Accuracy is 24.58%
# mlp.optimisers:INFO Epoch 17: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 18: Training cost (ce) is 3.378. Accuracy is 27.70%
# mlp.optimisers:INFO Epoch 18: Validation cost (ce) is 2.417. Accuracy is 27.36%
# mlp.optimisers:INFO Epoch 18: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 19: Training cost (ce) is 3.611. Accuracy is 26.40%
# mlp.optimisers:INFO Epoch 19: Validation cost (ce) is 3.347. Accuracy is 30.18%
# mlp.optimisers:INFO Epoch 19: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 20: Training cost (ce) is 4.180. Accuracy is 25.80%
# mlp.optimisers:INFO Epoch 20: Validation cost (ce) is 3.401. Accuracy is 26.97%
# mlp.optimisers:INFO Epoch 20: Took 235 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 21: Training cost (ce) is 4.135. Accuracy is 25.50%
# mlp.optimisers:INFO Epoch 21: Validation cost (ce) is 3.871. Accuracy is 19.96%
# mlp.optimisers:INFO Epoch 21: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 22: Training cost (ce) is 4.259. Accuracy is 24.30%
# mlp.optimisers:INFO Epoch 22: Validation cost (ce) is 5.661. Accuracy is 27.25%
# mlp.optimisers:INFO Epoch 22: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 23: Training cost (ce) is 4.024. Accuracy is 25.90%
# mlp.optimisers:INFO Epoch 23: Validation cost (ce) is 3.776. Accuracy is 21.16%
# mlp.optimisers:INFO Epoch 23: Took 236 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 24: Training cost (ce) is 4.213. Accuracy is 23.70%
# mlp.optimisers:INFO Epoch 24: Validation cost (ce) is 4.765. Accuracy is 20.98%
# mlp.optimisers:INFO Epoch 24: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 25: Training cost (ce) is 5.460. Accuracy is 21.90%
# mlp.optimisers:INFO Epoch 25: Validation cost (ce) is 4.077. Accuracy is 28.57%
# mlp.optimisers:INFO Epoch 25: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 26: Training cost (ce) is 5.301. Accuracy is 23.80%
# mlp.optimisers:INFO Epoch 26: Validation cost (ce) is 5.879. Accuracy is 28.06%
# mlp.optimisers:INFO Epoch 26: Took 237 seconds. Training speed 23 pps. Validation speed 52 pps.
# mlp.optimisers:INFO Epoch 27: Training cost (ce) is 5.168. Accuracy is 24.50%
# mlp.optimisers:INFO Epoch 27: Validation cost (ce) is 3.050. Accuracy is 31.82%
# mlp.optimisers:INFO Epoch 27: Took 238 seconds. Training speed 23 pps. Validation speed 51 pps.
# mlp.optimisers:INFO Epoch 28: Training cost (ce) is 4.488. Accuracy is 26.70%
# mlp.optimisers:INFO Epoch 28: Validation cost (ce) is 4.973. Accuracy is 25.05%
# mlp.optimisers:INFO Epoch 28: Took 238 seconds. Training speed 23 pps. Validation speed 51 pps.
# mlp.optimisers:INFO Epoch 29: Training cost (ce) is 4.660. Accuracy is 25.60%
# mlp.optimisers:INFO Epoch 29: Validation cost (ce) is 3.727. Accuracy is 25.58%
# mlp.optimisers:INFO Epoch 29: Took 240 seconds. Training speed 23 pps. Validation speed 51 pps.
# mlp.optimisers:INFO Epoch 30: Training cost (ce) is 4.802. Accuracy is 23.40%
# mlp.optimisers:INFO Epoch 30: Validation cost (ce) is 6.116. Accuracy is 22.55%
# mlp.optimisers:INFO Epoch 30: Took 241 seconds. Training speed 23 pps. Validation speed 51 pps.
# root:INFO Testing the model on test set:
# root:INFO MNIST test set accuracy is 24.02 %, cost (ce) is 6.062
