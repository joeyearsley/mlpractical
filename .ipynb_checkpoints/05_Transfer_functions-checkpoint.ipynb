# %% [markdown]
# # Introduction
#
# This tutorial focuses on implementation of alternatives to sigmoid transfer functions for hidden units.  (*Transfer functions* are also called *activation functions* or *nonlinearities*.) First, we will work with hyperboilc tangent (tanh) and then unbounded (or partially unbounded) piecewise linear functions: Rectifying Linear Units (ReLU) and Maxout.
#
#
# ## Virtual environments
#
# Before you proceed onwards, remember to activate your virtual environment by typing `activate_mlp` or `source ~/mlpractical/venv/bin/activate` (or if you did the original install the "comfy way" type: `workon mlpractical`).
#
#
# ## Syncing the git repository
#
# Look <a href="https://github.com/CSTR-Edinburgh/mlpractical/blob/master/gitFAQ.md">here</a> for more details. But in short, we recommend to create a separate branch for this lab, as follows:
#
# 1. Enter the mlpractical directory `cd ~/mlpractical/repo-mlp`
# 2. List the branches and check which are currently active by typing: `git branch`
# 3. If you have followed our recommendations, you should be in the `lab4` branch, please commit your local changed to the repo index by typing:
# ```
# git commit -am "finished lab4"
# ```
# 4. Now you can switch to `master` branch by typing:
# ```
# git checkout master
#  ```
# 5. To update the repository (note, assuming master does not have any conflicts), if there are some, have a look <a href="https://github.com/CSTR-Edinburgh/mlpractical/blob/master/gitFAQ.md">here</a>
# ```
# git pull
# ```
# 6. And now, create the new branch & switch to it by typing:
# ```
# git checkout -b lab5
# ```

# %% [markdown]
# # Overview of alternative transfer functions
#
# Now, we briefly summarise some other possible choices for hidden layer transfer functions.
#
# ## Tanh
#
# Given a linear activation $a_{i}$ tanh implements the following operation:
#
# (1) $h_i(a_i) = \mbox{tanh}(a_i) = \frac{\exp(a_i) - \exp(-a_i)}{\exp(a_i) + \exp(-a_i)}$
#
# Hence, the derivative of $h_i$ with respect to $a_i$ is:
#
# (2) $\begin{align}
# \frac{\partial h_i}{\partial a_i} &= 1 - h^2_i
# \end{align}
# $
#
#
# ## ReLU
#
# Given a linear activation $a_{i}$ relu implements the following operation:
#
# (3) $h_i(a_i) = \max(0, a_i)$
#
# Hence, the gradient is :
#
# (4) $\begin{align}
# \frac{\partial h_i}{\partial a_i} &=
# \begin{cases}
#      1     & \quad \text{if } a_i > 0 \\
#      0       & \quad \text{if } a_i \leq 0 \\
# \end{cases}
# \end{align}
# $
#
# ReLU implements a form of data-driven sparsity, that is, on average the activations are sparse (many of them are 0) but the general sparsity pattern will depend on particular data-point. This is different from sparsity obtained in model's parameters one can obtain with $L1$ regularisation as the latter affect all data-points in the same way.
#
# ## Maxout
#
# Maxout is an example of data-driven type of non-linearity in which the transfer function can be learned from data. That is, the model can build a non-linear transfer function from piecewise linear components.  These linear components, depending on the number of linear regions used in the pooling operator (given by parameter $K$), can approximate  arbitrary functions, such as ReLU, abs, etc.
#
# Given some subset (group, pool) of $K$ linear activations $a_{j}, a_{j+1}, \ldots, a_{j+K}$ at the $l$-th layer, maxout implements the following operation:
#
# (5) $h_i(a_j, a_{j+1}, \ldots, a_{j+K}) = \max(a_j, a_{j+1}, \ldots, a_{j+K})$
#
# Hence, the gradient of $h_i$ w.r.t to the pooling region $a_{j}, a_{j+1}, \ldots, a_{j+K}$  is :
#
# (6) $\begin{align}
# \frac{\partial h_i}{\partial (a_j, a_{j+1}, \ldots, a_{j+K})} &=
# \begin{cases}
#      1     & \quad \text{for the max activation}  \\
#      0       & \quad \text{otherwise} \\
# \end{cases}
# \end{align}
# $
#
# Implementation tips are given in Exercise 3.
#
# # On weight initialisation
#
# Activation functions directly affect the "network dynamics", that is, the magnitudes of the statistics each layer is producing. For example, *squashing* non-linearities like sigmoid or tanh bring the linear activations to a certain bounded range. ReLU, on the contrary, has an unbounded positive side. This directly affects all statistics collected in forward and backward passes as well as the gradients w.r.t paramters - hence also the pace at which the model learns. That is why learning rate is usually required to be tuned for given the characterictics of the non-linearities used.
#
# Another important hyperparameter is the initial range used to initialise the weight matrices.  We have largely ignored it so far (although if you did further experiments in coursework 1, you may have found setting it had an effect on training deeper networks with 4 or 5 hidden layers).  However, for sigmoidal non-linearities (sigmoid, tanh) the initialisation range is an important hyperparameter and a considerable amount of research has been put into determining what is the best strategy for choosing it. In fact, one of the early triggers of the recent resurgence of deep learning was pre-training - techniques for initialising weights in an unsupervised manner so that one can effectively train deeper models in supervised fashion later.
#
# ## Sigmoidal transfer functions
#
# Y. LeCun in [Efficient Backprop](http://link.springer.com/chapter/10.1007%2F3-540-49430-8_2) recommends the following setting of the initial range $r$ for sigmoidal units (assuming that the data has been normalised to zero mean, unit variance):
#
# (7) $ r = \frac{1}{\sqrt{N_{IN}}} $
#
# where $N_{IN}$ is the number of inputs to the given layer and the weights are then sampled from the (usually uniform) distribution $U(-r,r)$. The motivation is to keep the initial forward-pass signal in the linear region of the sigmoid non-linearity so that the gradients are large enough for training to proceed (note that the sigmoidal non-linearities saturate when activations are either very positive or very negative, leading to very small gradients and hence poor learning dynamics).
#
# The initialisation used in (7) however leads to different magnitudes of activations/gradients at different layers (due to multiplicative nature of the computations) and more recently, [Glorot et. al](http://jmlr.org/proceedings/papers/v9/glorot10a/glorot10a.pdf) proposed the so-called *normalised initialisation*, which ensures the variance of the forward signal (activations) is approximately the same in each layer. The same applies to the gradients obtained in backward pass.
#
# The $r$ in the *normalised initialisation* for $\mbox{tanh}$ non-linearity is then:
#
# (8) $ r = \frac{\sqrt{6}}{\sqrt{N_{IN}+N_{OUT}}} $
#
# For the sigmoid (logistic) non-linearity, to get similiar characteristics, one should scale $r$ in (8) by 4, that is:
#
# (9) $ r = \frac{4\sqrt{6}}{\sqrt{N_{IN}+N_{OUT}}} $
#
# ## Piece-wise linear transfer functions (ReLU, Maxout)
#
# For unbounded transfer functions initialisation is not as crucial as for sigmoidal ones. This is due to the fact that their gradients do not diminish (they are acutally more likely to explode) and they do not saturate (ReLU saturates at 0, but not on the positive slope, where gradient is 1 everywhere).  (In practice ReLU is sometimes "clipped" with a maximum value, typically 20).

# %% [markdown]
# # Exercise 1:  Implement the tanh transfer function
#
# Your implementation should follow the code conventions used to build other layer types (for example, Sigmoid and Softmax). Test your solution by training a one-hidden-layer model with 100 hidden units, similiar to the one used in Task 3a in the coursework.
#
# Tune the learning rate and compare the initial ranges in equations (7) and (8). Note that there might not be much difference for one-hidden-layer model, but you can easily notice a substantial gain from using (8) (or (9) for  logistic sigmoid activation) for deeper models, for example, the 5 hidden-layer network from the first coursework.
#
# Implementation tip: Use numpy.tanh() to compute the non-linearity.  Use the irange argument when creating the given layer type to provide the initial sampling range.

# %%
from mlp.layers import Linear

class Tanh(Linear):
    def __init__(self,  idim, odim,
                 rng=None,
                 irange=0.1):

        super(Tanh, self).__init__(idim, odim, rng, irange)
    
    def fprop(self, inputs):
        #get the linear activations
        a = super(Tanh, self).fprop(inputs)
        #stabilise the exp() computation in case some values in
        #'a' get very negative. We limit both tails, however only
        #negative values may lead to numerical issues -- exp(-a)
        #clip() function does the following operation faster:
        # a[a < -30.] = -30,
        # a[a > 30.] = 30.
        numpy.clip(a, -30.0, 30.0, out=a)
        h = numpy.tanh(a)
        return h
    
    def bprop(self, h, igrads):
        dsigm = 1 - numpy.square(h)
        deltas = igrads * dsigm
        ___, ograds = super(Tanh, self).bprop(h=None, igrads=deltas)
        return deltas, ograds
    
    

import numpy
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

from mlp.layers import MLP, Linear, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

rng = numpy.random.RandomState([2015,10,10])

# define the model structure, here just one linear layer
# and mean square error cost
cost = CECost()
model = MLP(cost=cost)
model.add_layer(Tanh(idim=784, odim=100, rng=rng))
model.add_layer(Softmax(idim=100, odim=10, rng=rng))
#one can stack more layers here

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs as stopping criterion
lr_scheduler = LearningRateFixed(learning_rate=0.01, max_epochs=20)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.info('Initialising data providers...')
train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

logger.info('Training started...')
optimiser.train(model, train_dp, valid_dp)

logger.info('Testing the model on test set:')
test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
cost, accuracy = optimiser.validate(model, test_dp)
logger.info('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))
# Out:
# INFO:root:Initialising data providers...
# INFO:root:Training started...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for initial model is 2.354. Accuracy is 11.49%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for initial model is 2.350. Accuracy is 12.02%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 1.506. Accuracy is 64.54%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 0.902. Accuracy is 82.78%
# INFO:mlp.optimisers:Epoch 1: Took 5 seconds. Training speed 10616 pps. Validation speed 28574 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 0.744. Accuracy is 83.40%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 0.571. Accuracy is 87.46%
# INFO:mlp.optimisers:Epoch 2: Took 5 seconds. Training speed 10439 pps. Validation speed 28574 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 0.551. Accuracy is 86.46%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 0.459. Accuracy is 89.02%
# INFO:mlp.optimisers:Epoch 3: Took 5 seconds. Training speed 10616 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 4: Training cost (ce) is 0.471. Accuracy is 87.72%
# INFO:mlp.optimisers:Epoch 4: Validation cost (ce) is 0.406. Accuracy is 89.67%
# INFO:mlp.optimisers:Epoch 4: Took 5 seconds. Training speed 10439 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 5: Training cost (ce) is 0.426. Accuracy is 88.51%
# INFO:mlp.optimisers:Epoch 5: Validation cost (ce) is 0.373. Accuracy is 90.26%
# INFO:mlp.optimisers:Epoch 5: Took 5 seconds. Training speed 10331 pps. Validation speed 25644 pps.
# INFO:mlp.optimisers:Epoch 6: Training cost (ce) is 0.397. Accuracy is 89.17%
# INFO:mlp.optimisers:Epoch 6: Validation cost (ce) is 0.351. Accuracy is 90.50%
# INFO:mlp.optimisers:Epoch 6: Took 5 seconds. Training speed 9709 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 7: Training cost (ce) is 0.375. Accuracy is 89.58%
# INFO:mlp.optimisers:Epoch 7: Validation cost (ce) is 0.334. Accuracy is 90.79%
# INFO:mlp.optimisers:Epoch 7: Took 5 seconds. Training speed 11062 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 8: Training cost (ce) is 0.359. Accuracy is 89.96%
# INFO:mlp.optimisers:Epoch 8: Validation cost (ce) is 0.322. Accuracy is 91.17%
# INFO:mlp.optimisers:Epoch 8: Took 5 seconds. Training speed 11087 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 9: Training cost (ce) is 0.346. Accuracy is 90.25%
# INFO:mlp.optimisers:Epoch 9: Validation cost (ce) is 0.312. Accuracy is 91.34%
# INFO:mlp.optimisers:Epoch 9: Took 5 seconds. Training speed 9804 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 10: Training cost (ce) is 0.335. Accuracy is 90.58%
# INFO:mlp.optimisers:Epoch 10: Validation cost (ce) is 0.303. Accuracy is 91.63%
# INFO:mlp.optimisers:Epoch 10: Took 5 seconds. Training speed 10965 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 11: Training cost (ce) is 0.326. Accuracy is 90.81%
# INFO:mlp.optimisers:Epoch 11: Validation cost (ce) is 0.295. Accuracy is 91.74%
# INFO:mlp.optimisers:Epoch 11: Took 5 seconds. Training speed 10081 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 12: Training cost (ce) is 0.317. Accuracy is 91.01%
# INFO:mlp.optimisers:Epoch 12: Validation cost (ce) is 0.289. Accuracy is 91.81%
# INFO:mlp.optimisers:Epoch 12: Took 5 seconds. Training speed 11161 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 13: Training cost (ce) is 0.310. Accuracy is 91.17%
# INFO:mlp.optimisers:Epoch 13: Validation cost (ce) is 0.283. Accuracy is 92.02%
# INFO:mlp.optimisers:Epoch 13: Took 5 seconds. Training speed 11087 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 14: Training cost (ce) is 0.303. Accuracy is 91.36%
# INFO:mlp.optimisers:Epoch 14: Validation cost (ce) is 0.277. Accuracy is 92.12%
# INFO:mlp.optimisers:Epoch 14: Took 6 seconds. Training speed 9560 pps. Validation speed 28574 pps.
# INFO:mlp.optimisers:Epoch 15: Training cost (ce) is 0.297. Accuracy is 91.56%
# INFO:mlp.optimisers:Epoch 15: Validation cost (ce) is 0.272. Accuracy is 92.29%
# INFO:mlp.optimisers:Epoch 15: Took 6 seconds. Training speed 9329 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 16: Training cost (ce) is 0.291. Accuracy is 91.69%
# INFO:mlp.optimisers:Epoch 16: Validation cost (ce) is 0.268. Accuracy is 92.43%
# INFO:mlp.optimisers:Epoch 16: Took 5 seconds. Training speed 11013 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 17: Training cost (ce) is 0.285. Accuracy is 91.88%
# INFO:mlp.optimisers:Epoch 17: Validation cost (ce) is 0.263. Accuracy is 92.45%
# INFO:mlp.optimisers:Epoch 17: Took 5 seconds. Training speed 10989 pps. Validation speed 29415 pps.
# INFO:mlp.optimisers:Epoch 18: Training cost (ce) is 0.280. Accuracy is 92.04%
# INFO:mlp.optimisers:Epoch 18: Validation cost (ce) is 0.259. Accuracy is 92.59%
# INFO:mlp.optimisers:Epoch 18: Took 6 seconds. Training speed 8389 pps. Validation speed 28574 pps.
# INFO:mlp.optimisers:Epoch 19: Training cost (ce) is 0.275. Accuracy is 92.15%
# INFO:mlp.optimisers:Epoch 19: Validation cost (ce) is 0.255. Accuracy is 92.73%
# INFO:mlp.optimisers:Epoch 19: Took 6 seconds. Training speed 8993 pps. Validation speed 18870 pps.
# INFO:mlp.optimisers:Epoch 20: Training cost (ce) is 0.271. Accuracy is 92.32%
# INFO:mlp.optimisers:Epoch 20: Validation cost (ce) is 0.252. Accuracy is 92.84%
# INFO:mlp.optimisers:Epoch 20: Took 6 seconds. Training speed 9075 pps. Validation speed 24393 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 92.66 % (cost is 0.259)

# %% [markdown]
# # Exercise 2: Implement ReLU
#
# Again, your implementation should follow the conventions used to build Linear, Sigmoid and Softmax layers. As in exercise 1, test your solution by training a one-hidden-layer model with 100 hidden units, similiar to the one used in Task 3a in the coursework. Tune the learning rate (start with the initial one set to 0.1) with the initial weight range set to 0.05.

# %%
from mlp.layers import Linear

class ReLu(Linear):
    def __init__(self,  idim, odim,
                 rng=None,
                 irange=0.1):

        super(ReLu, self).__init__(idim, odim, rng, irange)
    
    def fprop(self, inputs):
        #get the linear activations
        a = super(ReLu, self).fprop(inputs)
        #limit to above 0 or return 0
        numpy.clip(a, 0.0, (float("inf")), out=a)
        return a
    
    def bprop(self, h, igrads):
        ''' [[row[i] for row in mat] for i in [0, 1, 2]] '''
        result = [[1 if a[i] > 0 else 0 for a in h.T] for i in xrange(0,len(h.T))]
        deltas = igrads * result
        ___, ograds = super(ReLu, self).bprop(h=None, igrads=deltas)
        return deltas, ograds
    
import numpy
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

from mlp.layers import MLP, Linear, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

rng = numpy.random.RandomState([2015,10,10])

# define the model structure, here just one linear layer
# and mean square error cost
cost = CECost()
model = MLP(cost=cost)
model.add_layer(ReLu(idim=784, odim=100, rng=rng))
model.add_layer(Softmax(idim=100, odim=10, rng=rng))
#one can stack more layers here

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs as stopping criterion
lr_scheduler = LearningRateFixed(learning_rate=0.01, max_epochs=20)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.info('Initialising data providers...')
train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

logger.info('Training started...')
optimiser.train(model, train_dp, valid_dp)

logger.info('Testing the model on test set:')
test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
cost, accuracy = optimiser.validate(model, test_dp)
logger.info('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))
# Out:
# INFO:root:Initialising data providers...
# INFO:root:Training started...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for initial model is 2.343. Accuracy is 13.65%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for initial model is 2.342. Accuracy is 13.98%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 1.590. Accuracy is 61.99%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 0.903. Accuracy is 82.79%
# INFO:mlp.optimisers:Epoch 1: Took 7 seconds. Training speed 7268 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 0.716. Accuracy is 83.66%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 0.533. Accuracy is 87.62%
# INFO:mlp.optimisers:Epoch 2: Took 7 seconds. Training speed 7226 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 0.517. Accuracy is 86.71%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 0.428. Accuracy is 89.18%
# INFO:mlp.optimisers:Epoch 3: Took 7 seconds. Training speed 7247 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 4: Training cost (ce) is 0.444. Accuracy is 88.06%
# INFO:mlp.optimisers:Epoch 4: Validation cost (ce) is 0.383. Accuracy is 89.74%
# INFO:mlp.optimisers:Epoch 4: Took 7 seconds. Training speed 7268 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 5: Training cost (ce) is 0.405. Accuracy is 88.90%
# INFO:mlp.optimisers:Epoch 5: Validation cost (ce) is 0.356. Accuracy is 90.45%
# INFO:mlp.optimisers:Epoch 5: Took 7 seconds. Training speed 7268 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 6: Training cost (ce) is 0.380. Accuracy is 89.41%
# INFO:mlp.optimisers:Epoch 6: Validation cost (ce) is 0.338. Accuracy is 90.53%
# INFO:mlp.optimisers:Epoch 6: Took 7 seconds. Training speed 7278 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 7: Training cost (ce) is 0.362. Accuracy is 89.82%
# INFO:mlp.optimisers:Epoch 7: Validation cost (ce) is 0.324. Accuracy is 91.00%
# INFO:mlp.optimisers:Epoch 7: Took 7 seconds. Training speed 7257 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 8: Training cost (ce) is 0.348. Accuracy is 90.20%
# INFO:mlp.optimisers:Epoch 8: Validation cost (ce) is 0.313. Accuracy is 91.41%
# INFO:mlp.optimisers:Epoch 8: Took 7 seconds. Training speed 7226 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 9: Training cost (ce) is 0.336. Accuracy is 90.49%
# INFO:mlp.optimisers:Epoch 9: Validation cost (ce) is 0.304. Accuracy is 91.61%
# INFO:mlp.optimisers:Epoch 9: Took 7 seconds. Training speed 7257 pps. Validation speed 33337 pps.
# INFO:mlp.optimisers:Epoch 10: Training cost (ce) is 0.326. Accuracy is 90.76%
# INFO:mlp.optimisers:Epoch 10: Validation cost (ce) is 0.297. Accuracy is 91.67%
# INFO:mlp.optimisers:Epoch 10: Took 7 seconds. Training speed 7236 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 11: Training cost (ce) is 0.318. Accuracy is 91.02%
# INFO:mlp.optimisers:Epoch 11: Validation cost (ce) is 0.290. Accuracy is 91.89%
# INFO:mlp.optimisers:Epoch 11: Took 8 seconds. Training speed 6640 pps. Validation speed 19233 pps.
# INFO:mlp.optimisers:Epoch 12: Training cost (ce) is 0.310. Accuracy is 91.21%
# INFO:mlp.optimisers:Epoch 12: Validation cost (ce) is 0.284. Accuracy is 91.99%
# INFO:mlp.optimisers:Epoch 12: Took 7 seconds. Training speed 7236 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 13: Training cost (ce) is 0.302. Accuracy is 91.42%
# INFO:mlp.optimisers:Epoch 13: Validation cost (ce) is 0.278. Accuracy is 92.22%
# INFO:mlp.optimisers:Epoch 13: Took 7 seconds. Training speed 7226 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 14: Training cost (ce) is 0.295. Accuracy is 91.61%
# INFO:mlp.optimisers:Epoch 14: Validation cost (ce) is 0.272. Accuracy is 92.46%
# INFO:mlp.optimisers:Epoch 14: Took 7 seconds. Training speed 7215 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 15: Training cost (ce) is 0.288. Accuracy is 91.82%
# INFO:mlp.optimisers:Epoch 15: Validation cost (ce) is 0.266. Accuracy is 92.51%
# INFO:mlp.optimisers:Epoch 15: Took 7 seconds. Training speed 7226 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 16: Training cost (ce) is 0.282. Accuracy is 91.97%
# INFO:mlp.optimisers:Epoch 16: Validation cost (ce) is 0.261. Accuracy is 92.69%
# INFO:mlp.optimisers:Epoch 16: Took 8 seconds. Training speed 6897 pps. Validation speed 32261 pps.
# INFO:mlp.optimisers:Epoch 17: Training cost (ce) is 0.276. Accuracy is 92.26%
# INFO:mlp.optimisers:Epoch 17: Validation cost (ce) is 0.257. Accuracy is 92.91%
# INFO:mlp.optimisers:Epoch 17: Took 7 seconds. Training speed 7247 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 18: Training cost (ce) is 0.270. Accuracy is 92.44%
# INFO:mlp.optimisers:Epoch 18: Validation cost (ce) is 0.251. Accuracy is 93.00%
# INFO:mlp.optimisers:Epoch 18: Took 7 seconds. Training speed 7205 pps. Validation speed 31253 pps.
# INFO:mlp.optimisers:Epoch 19: Training cost (ce) is 0.265. Accuracy is 92.57%
# INFO:mlp.optimisers:Epoch 19: Validation cost (ce) is 0.247. Accuracy is 93.16%
# INFO:mlp.optimisers:Epoch 19: Took 7 seconds. Training speed 7205 pps. Validation speed 30306 pps.
# INFO:mlp.optimisers:Epoch 20: Training cost (ce) is 0.259. Accuracy is 92.73%
# INFO:mlp.optimisers:Epoch 20: Validation cost (ce) is 0.243. Accuracy is 93.15%
# INFO:mlp.optimisers:Epoch 20: Took 7 seconds. Training speed 7226 pps. Validation speed 32261 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 93.09 % (cost is 0.248)

# %% [markdown]
# # Exercise 3: Implement Maxout
#
# As with the previous two exercises, your implementation should follow the conventions used to build the Linear, Sigmoid and Softmax layers. For now implement only non-overlapping pools (i.e. the pool in which all activations $a_{j}, a_{j+1}, \ldots, a_{j+K}$ belong to only one pool). As before, test your solution by training a one-hidden-layer model with 100 hidden units, similiar to the one used in Task 3a in the coursework. Use the same optimisation hyper-parameters (learning rate, initial weights range) as you used for ReLU models. Tune the pool size $K$ (but keep the number of total parameters fixed).
#
# Note: The Max operator reduces dimensionality, hence for example, to get 100 hidden maxout units with pooling size set to $K=2$ the size of linear part needs to be set to $100K$ (assuming non-overlapping pools). This affects how you compute the total number of weights in the model.
#
# Implementation tips: To back-propagate through the maxout layer, one needs to keep track of which linear activation $a_{j}, a_{j+1}, \ldots, a_{j+K}$ was the maximum in each pool. The convenient way to do so is by storing the indices of the maximum units in the fprop function and then in the backprop stage pass the gradient only through those (i.e. for example, one can build an auxiliary matrix where each element is either 1 (if unit was maximum, and passed forward through the max operator for a given data-point) or 0 otherwise. Then in the backward pass it suffices to upsample the maxout *igrads* signal to the linear layer dimension and element-wise multiply by the aforemenioned auxiliary matrix.
#
# *Optional:* Implement the generic pooling mechanism by introducing an additional *stride* hyper-parameter $0<S\leq K$. It specifies how many units you move to build the next pool. For instance, for non-overlapping pooling with $S=K=3$ one would build the first two maxout units as: $h_1=\max(a_1,a_2,a_3)$ and $h_2=\max(a_4,a_5,a_6)$. However, after setting $S=1$ the pools should share some subset of linear activations: $h_1=\max(a_1,a_2,a_3)$ and $h_2=\max(a_2,a_3,a_4)$.

# %% [markdown]
# # Exercise 4: Train all the above models with dropout
#
# Try all of the above non-linearities with dropout training. Use the dropout hyper-parameters $\{p_{inp}, p_{hid}\}$ that worked best for sigmoid models from the previous lab.
#
# Note: the code for dropout you were asked to implement last week has not been given as a solution for this week - as a result you need to move/merge the required dropout parts from your previous *lab4* branch (or implement it if you haven't already done so).
